# %%
# Вызываем необходимые библиотеки 
import matplotlib.pyplot as plt

# Вызываем средство генерации облаков точек 
from sklearn.datasets.samples_generator import make_blobs 

from sklearn import svm

# Создаём датасет X, содержащий 500 объектов 
# Значение Y определяет наличие двух классов в выборке
X, Y = make_blobs(n_samples = 500, centers = 2, 
                  random_state = 0, cluster_std = 0.40) 
  
# Наносим точки на график  
plt.scatter(X[:, 0], X[:, 1], c = Y, s = 40); 
plt.show()

# Подбираем модель
for kernel in ('linear'):
    clf = svm.SVC(kernel='linear', gamma=2)
    clf.fit(X, Y)

    # Построение линий и точек
    plt.figure(fignum, figsize=(4, 3))
    plt.clf()

    plt.scatter(X[:, 0], X[:, 1], c=Y, zorder=2, cmap=plt.cm.Paired,
                edgecolors='b')

    plt.axis('tight')
    x_min = -1
    x_max = 4
    y_min = -1
    y_max = 6

    XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
    Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Отображаем результаты на рисунке
    Z = Z.reshape(XX.shape)
    plt.figure(fignum, figsize=(4, 3))
    plt.pcolormesh(XX, YY, Z > 0, cmap=plt.cm.Paired)
    plt.contour(XX, YY, Z, colors=['w'], linestyles=['-'], levels=[0])

    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)

    plt.xticks(())
    plt.yticks(())
    
plt.show()

# %%
# Вызываем необходимые библиотеки
import matplotlib.pyplot as plt

# Вызываем средство генерации точек, размещённых в пределах окружности
from sklearn.datasets import make_circles

# Генератор случайных значений с учётом seed
np.random.seed(0)

# Создаём датасет, содержащий 300 объектов, разделённых
# на две области (кольцо и круг) путём подбора значения параметра factor
X, Y = make_circles(n_samples=300, factor=.2, noise=.1)

# Отрисовка выборки
plt.figure()
plt.subplot(2, 2, 1, aspect='equal')
plt.title("Исходные данные")
reds = y == 0
blues = y == 1

plt.scatter(X[reds, 0], X[reds, 1], c="red",
            s=20, edgecolor='k')
plt.scatter(X[blues, 0], X[blues, 1], c="blue",
            s=20, edgecolor='k')
plt.xlabel("$x1$")
plt.ylabel("$x2$")

# Подбор модели
for kernel in ('rbf'):
    clf = svm.SVC(kernel='rbf', gamma=5)
    clf.fit(X, Y)

    # Отрисовка кривых и точек (объектов выборки)
    plt.figure(fignum, figsize=(4, 3))
    plt.clf()

    plt.scatter(X[:, 0], X[:, 1], c=Y, zorder=2, cmap=plt.cm.Paired, edgecolors='blue')
 
    plt.axis('tight')
    x_min = -1.5
    x_max = 1.5
    y_min = -1.5
    y_max = 1.5

    XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
    Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Отрисовка результата
    Z = Z.reshape(XX.shape)
    plt.figure(fignum, figsize=(4, 3))
    plt.pcolormesh(XX, YY, Z > 0, cmap=plt.cm.Paired)
    plt.contour(XX, YY, Z, colors=['w'], linestyles=['-'], levels=[0])

    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)

    plt.xticks(())
    plt.yticks(())

plt.show()
